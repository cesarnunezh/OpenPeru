# %%
import fitz  # PyMuPDF
import pytesseract
import cv2
import numpy as np
from PIL import Image
from pathlib import Path
import re
import json

# %%
# (Opcional) Define ruta a Tesseract si no está en el PATH
pytesseract.pytesseract.tesseract_cmd = r"C:/Program Files/Tesseract-OCR/tesseract.exe"

pdf_path = Path("../data/test_votes.pdf")

doc = fitz.open(pdf_path)

pages = []

# for everypage
for i, page in enumerate(doc):
    # Renderiza la página como imagen (aumentando resolución)
    pix = page.get_pixmap(dpi=300)
    img_data = np.frombuffer(pix.samples, dtype=np.uint8).reshape(
        pix.height, pix.width, pix.n
    )

    # Convierte a escala de grises
    gray = cv2.cvtColor(img_data, cv2.COLOR_RGB2GRAY)

    # (Opcional) Umbralizar para mejorar OCR
    _, thresh = cv2.threshold(gray, 180, 255, cv2.THRESH_BINARY)

    # Convierte imagen para OCR
    pil_img = Image.fromarray(thresh)

    # Ejecuta OCR con layout de columnas
    text = pytesseract.image_to_string(
        pil_img, lang="spa", config="--psm 6"
    )  # psm 6: Assume a uniform block of text

    pages.append(text)

    print(f"\n--- Página {i + 1} ---\n")
    print(text)
# Out:
# --- Página 1 ---
#
# CONGRESO DE LA REPÚBLICA DEL PERÚ
#
# Segunda Legislatura Ordinaria 2024-2025
# Sesión del 20 de marzo de 2025
# ASISTENCIA: — Fecha: 20/03/2025 Hora: 06:50 pm
# APP ACUÑA PERALTA, MARÍA GRIMANEZA PRE BS FLORES RAMÍREZ, ALEX RANDU PRE 8M PAREDES GONZALES, ALEX ANTONIO PRE
# HYD ACUÑA PERALTA, SEGUNDO HÉCTOR PRE FP FLORES RUIZ, VÍCTOR SEFERINO PRE BDP PAREDES PIQUÉ, SUSEL ANA MARÍA PRE
# PL AGUERO GUTIÉRREZ, MARÍA ANTONIETA PRE APP GARCÍA CORREA, IDELSO MANUEL LE BS PARIONA SINCHE, ALFREDO PRE
# FP AGUINAGA RECUENCO, ALEJANDRO PRE PL GONZA CASTILLO, AMÉRICO PRE sP PAZO NUNURA, JOSÉ BERNARDO PRE
# PP ALCARRAZ AGUERO, YOREL KIRA LP AP-PIS GONZALES DELGADO, DIANA CAROLINA — PRE PP PICÓN QUEDO, LUIS RAÚL PRE
# FP ALEGRÍA GARCÍA, ARTURO PRE EM GUTIÉRREZ TICONA, PAUL SILVIO LP PL PORTALATINO ÁVALOS, KELLY ROXANA — aus
# NA ALVA PRIETO, MARÍA DEL CARMEN PRE APP HETDINGER BALLESTEROS, NELCY PRE AP PORTERO LÓPEZ, HILDA MARLENY LP
# AP ALVA ROJAS, CARLOS ENRIQUE PRE RP HERRERA MEDINA, NOELIA ROSSVITH PRE BM QUIROZ BARBOZA, SEGUNDO TEODOMIRO PRE
# AP-PIS AMURUZ DULANTO, YESSICA ROSSELLI LE FP HUAMÁN CORONADO, RAÚL PRE JPP-VP QUISPE MAMANI, WILSON RUSBEL PRE
# NA ANDERSON RAMÍREZ, CARLOS ANTONIO LE FP INFANTES CASTAÑEDA, MERY ELIANA aus 8s QUITO SARMIENTO, BERNARDO JATME PRE
# Com. EXt. Internacional (CET) 0 eM BLOQUE MAGISTERIAL DE CONCERTACIÓN NACITONAL 6 1 1 0 0
# Junta de Portavoces (JP) 0 JPP-VP JUNTOS POR EL PERÚ - VOCES DEL PUEBLO 8 0 0 0 0
# Bancada CBan) 0 AP-PIS AVANZA PAÍS - PARTIDO DE INTEGRACIÓN SOCIAL 5 0 2 0 0
# Suspendidos Csus) 0 sP SOMOS PERÚ 6 1 0 0 0
# Fallecidos (F) 0 BS BANCADA SOCIALISTA 5 0 [o) 0 0
#
# HYD HONOR Y DEMOCRACIA 5 0 0 0 0
# Asistencia para Quórum 58 eBpbP BLOQUE DEMOCRÁTICO POPULAR 4 0 1 0 0
# Quórum ALCANZADO NA NO AGRUPADOS Qí 3 0 2 0 0
#
# e DE LA REy > « dE L /;¿¡¿,03$
# S n7 Á N €
#
# S vB 1 / VB A
#
# e SANTILGA MÉNDEZ * A DAVILA =
#
# '¿;b ¿_9 .'_ 4k x
#
# 0% * , ' S
# '?ºlatotx'¿ ”£'Re|at v | 31337 - 47560 - 07830
#
#
# --- Página 2 ---
#
# CONGRESO DE LA REPÚBLICA DEL PERÚ
#
# Segunda Legislatura Ordinaria 2024-2025 *** Presidente: JUÁREZ GALLEGOS, CARMEN PATRICIA
# Sesión del 20 de marzo de 2025
# VOTACIÓN: Fecha: 20/03/2025 Hora: 06:53 pm
# Asunto:
# TEXTO SUSTITUTORIO DE LOS PROYECTOS DE LEY 9952 Y 10324, QUE PROPONEN MODIFICAR LA LEY 26859, LEY ORGÁNICA DE
# ELECCIONES, PARA REGULAR EL REGUENTO DE VOTOS
# APP ACUÑA PERALTA, MARÍA GRIMANEZA SI 4+++ BS FLORES RAMÍREZ, ALEX RANDU NO --- BM PAREDES GONZALES, ALEX ANTONIO SI +++
# HYD ACUÑA PERALTA, SEGUNDO HÉCTOR SI +++ FP FLORES RUIZ, VÍCTOR SEFERINO SI +++ BDP PAREDES PIQUÉ, SUSEL ANA MARÍA NO ---
# PL AGUERO GUTIÉRREZ, MARÍA ANTONIETA SI +++ APP GARCÍA CORREA, IDELSO MANUEL LE BS PARIONA SINCHE, ALFREDO NO ---
# FP AGUINAGA RECUENCO, ALEJANDRO SI ++ PL GONZA CASTILLO, AMÉRICO SI +++ SP PAZO NUNURA, JOSÉ BERNARDO SI +++
# PP ALCARRAZ AGUERO, YOREL KIRA LP AP-PIS GONZALES DELGADO, DIANA CAROLINA — SI +++ PP PICÓN QUEDO, LUIS RAÚL NO ---
# FP ALEGRÍA GARCÍA, ARTURO SI +++ BM GUTIÉRREZ TICONA, PAUL SILVIO LP PL PORTALATINO ÁVALOS, KELLY ROXANA aus
# NA ALVA PRIETO, MARÍA DEL CARMEN SI +++ APP HEIDINGER BALLESTEROS, NELCY SI +++ AP PORTERO LÓPEZ, HILDA MARLENY LP
# AP ALVA ROJAS, CARLOS ENRIQUE SI +++ RP HERRERA MEDINA, NOELIA ROSSVITH — SI +4+ BM QUIROZ BARBOZA, SEGUNDO TEODOMIRO SI +++
# Resultados de VOTACIÓN Grupo Parlamentario Si+++  No--- Ab€ S“º 7
# SI+++ 69 FP FUERZA POPULAR 19 0 MJe SANTILUA MENDEZ t
# NO--- 26 APP ALIANZA PARA EL PROGRESO - 8 0 aZ 0 o
# Abst. 1 PP PODEMOS PERÚ 1 7 " % 0 .¡,
# sinres 1 P PERÚ LIBRE 5 1 o helait>
# Ausentes CAus) 17 RP RENOVACIÓN POPULAR 7 0 0 0
# con licencia oficial (Lo) 2 AP ACCIÓN POPULAR 5 0 0 YE
# Licencia por enfermedad (LE) 7 BM BLOQUE MAGISTERIAL DE CONCERTACIÓN NACIONAL 6 0 0 g&úºo
# Licencia personal CLP) 7 JPP-VP JUNTOS POR EL PERÚ - VOCES DEL PUEBLO 0 8 [o) 3 B
# comisión ordinaria CCom) 0 AP-PIS AVANZA PAÍS - PARTIDO DE INTEGRACIÓN SOCIAL 5 0 0 A. DA
# Com. EXt. Internacional (CEI) ( SOMOS PERÚ 6 0 0 —
# Junta de Portavoces (IP) 0 BS BANCADA SOCIALISTA 0 5 0 %' 0 |
# Bancada (Ban) 0 HYD — HONOR Y DEMOCRACIA 5 0 o ººº¡?8¿ 0as
# Suspendidos (sus) 0 BDP BLOQUE DEMOCRÁTICO POPULAR 0 4 0 U
# Fallecidos (F) 0 NA NO AGRUPADOS 2 1 0 0
#
# La congresista Juárez Gallegos, primera vicepresidenta del Congreso, en ejercicio de la Presidencia deja
#
# constancia de su voto a favor; del voto a favor de los congresistas Gutiérrez Ticona, Flores Ancachi; y del
#
# voto en contra del congresista Tello Montes.
# *** En este reporte de votación no se considera al congresista que ejerce la presidencia. 31337 - 47560 - 08489

# %%
vote_page = pages[1]

vote_page = vote_page.replace("\n", " ")

# print (vote_page)

# jaro-winckler

parties_abbv = [
    " AP ",
    " AP-PIS ",
    " APP ",
    " BM ",
    " BDP ",
    " BOP ",
    " BS ",
    " BSS ",
    " E ",
    " FP ",
    " HYD ",
    " JP ",
    " IJPP-VP ",
    " JPP-VP ",
    " NA ",
    " NP ",
    " PL ",
    " PLG ",
    " PM ",
    " PP ",
    " SP ",
    " sP ",
    " RP ",
]  # might need to review and make sure everyone is here

sorted_parties = sorted(parties_abbv, key=len, reverse=True)
pattern = r"(?=" + "|".join(re.escape(party) for party in sorted_parties) + r")"

print(sorted_parties)
# Out:
# [' IJPP-VP ', ' AP-PIS ', ' JPP-VP ', ' APP ', ' BDP ', ' BOP ', ' BSS ', ' HYD ', ' PLG ', ' AP ', ' BM ', ' BS ', ' FP ', ' JP ', ' NA ', ' NP ', ' PL ', ' PM ', ' PP ', ' SP ', ' sP ', ' RP ', ' E ']

# %%
politician_list = re.split(pattern, vote_page)

string_list = []

for string in politician_list:
    if string[:4] or string[:5] in sorted_parties:
        string_list.append(string[1:])

string_list = string_list[1:131]

string_list[129] = string_list[129].split("¿")[0].strip()

print(string_list)
# Out:
MACHI QUISPE, NIEVES ESMERALDA NO -——', 'APP RUIZ RODRÍGUEZ, MAGALY ROSMERY LE', 'IJPP-VP BERMEJO ROJAS, GUILLERMO NO -—-', 'APP LIZARZABURU LIZARZABURU, JUAN C. LE', 'APP SALHUANA CAVIDES, EDUARDO aus', 'PP BURGOS OLIVEROS, JUAN BARTOLOMÉ SI +++', 'FP LÓPEZ MORALES, JENY LUZ SI +++', 'JPP-VP SÁNCHEZ PALOMINO, ROBERTO HELBERT NO ---', 'FP BUSTAMANTE DONAYRE, ERNESTO SI +++', 'AP LÓPEZ UREÑA, ILICH FREDY SI +++', 'FP SANTISTEBAN SUCLUPE, MAGALLY SI +++', 'PP CALLE LOBATÓN, DIGNA LP', 'PP LUNA GÁLVEZ, JOSÉ LEÓN aus', 'AP SOTO PALACIOS, WILSON SI +++', 'APP CAMONES SORIANO, LADY MERCEDES aus', 'BDP LUQUE IBARRA, RUTH NO --', 'APP SOTO REYES, ALEJANDRO SI +++', 'FP CASTILLO RIVAS, EDUARDO ENRIQUE SI +4++', 'AP-PIS MÁLAGA TRILLO, GEORGE EDWARD SI +++', 'BM TACURI VALDIVIA, GERMÁN ADOLFO SI +++', 'AP-PIS CAVERO ALVA, ALEJANDRO ENRIQUE SI +1++', 'APP MARTICORENA MENDOZA, JORGE SI +++', 'PL TAIPE CORONADO, MARÍA ELIZABETH LO', 'PL CERRÓN ROJAS, WALDEMAR JOSÉ Lo', 'NA MARTÍNEZ TALAVERA, PEDRO EDWIN SI +++', 'PP TELLO MONTES, NIVARDO EDGAR aus', 'FP CHACÓN TRUJILLO, NILZA MERLY SI +1++', 'BM MEDINA HERMOSILLA, ELIZABETH SARA SI +++', 'APP TORRES SALINAS, ROSIO aus', 'APP CHIABRA LEÓN, ROBERTO ENRIQUE SI +1++', 'RP MEDINA MINAYA, ESDRAS RICARDO SI +++', 'RP TRIGOZO REÁTEGUI, CHERYL aus', 'RP CHIRINOS VENEGAS, PATRICIA ROSA SI +++', 'PL MITA ALANOCA, ISAAC SI +++', 'AP-PIS TUDELA GUTIÉRREZ, ADRIANA JOSEFINA SI +++', 'RP CICCIA VÁSQUEZ, MIGUEL ANGEL P', 'PL MONTALVO CUBAS, SEGUNDO TORIBIO SI 4+++', 'BM UGARTE MAMANI, JHAKELINE KATY SI +++', 'JPP-VP COAYLA JUÁREZ, JORGE SAMUEL NO —-—', 'AP MONTEZA FACHO, SILVIA MARÍA SI +++', 'SP VALER PINTO, HÉCTOR SI +++', 'sP CORDERO JON TAY, LUIS GUSTAVO SI +4++', 'HYD MONTOYA MANRIQUE, JORGE SI +++', 'JPP-VP VARAS MELÉNDEZ, ELÍAS MARCIAL NO --', 'RP CÓRDOV ...

# %%
vote_results = [
    "SI",
    "NO",
    "Abst.",
    "SinRes",
    "aus",
    "LO",
    "LE",
    "LP",
    "Com",
    "CEI",
    "JP",
    "Ban",
    "Sus",
    "F",
]

final_list = []

for poltician_vote in string_list:
    return_dict = {}
    politician_name = ""
    end_vote = None
    vote_as_list = re.split(", | ", poltician_vote)
    party = vote_as_list[0]
    return_dict["party"] = party
    potential_name = vote_as_list[1:5]
    if len(potential_name[3]) > 3:
        first = potential_name[:2]
        last = potential_name[2:]
        return_name = last + first
        politician_name = " ".join(return_name)
    else:
        first = potential_name[:2]
        last = [potential_name[2]]
        return_name = last + first
        politician_name = " ".join(return_name)
    return_dict["name"] = politician_name
    for entry in vote_as_list[4:]:
        if entry in vote_results:
            return_dict["vote"] = entry
            break
    final_list.append(return_dict)

print(final_list)
# Out:
# [{'party': 'APP', 'name': 'MARÍA GRIMANEZA ACUÑA PERALTA', 'vote': 'SI'}, {'party': 'BS', 'name': 'ALEX RANDU FLORES RAMÍREZ', 'vote': 'NO'}, {'party': 'BM', 'name': 'ALEX ANTONIO PAREDES GONZALES', 'vote': 'SI'}, {'party': 'HYD', 'name': 'SEGUNDO HÉCTOR ACUÑA PERALTA', 'vote': 'SI'}, {'party': 'FP', 'name': 'VÍCTOR SEFERINO FLORES RUIZ', 'vote': 'SI'}, {'party': 'BDP', 'name': 'SUSEL PAREDES PIQUÉ', 'vote': 'NO'}, {'party': 'PL', 'name': 'MARÍA ANTONIETA AGUERO GUTIÉRREZ', 'vote': 'SI'}, {'party': 'APP', 'name': 'IDELSO MANUEL GARCÍA CORREA', 'vote': 'LE'}, {'party': 'BS', 'name': 'ALFREDO PARIONA SINCHE', 'vote': 'NO'}, {'party': 'FP', 'name': 'ALEJANDRO AGUINAGA RECUENCO', 'vote': 'SI'}, {'party': 'PL', 'name': 'AMÉRICO GONZA CASTILLO', 'vote': 'SI'}, {'party': 'SP', 'name': 'JOSÉ BERNARDO PAZO NUNURA', 'vote': 'SI'}, {'party': 'PP', 'name': 'YOREL KIRA ALCARRAZ AGUERO', 'vote': 'LP'}, {'party': 'AP-PIS', 'name': 'DIANA CAROLINA GONZALES DELGADO', 'vote': 'SI'}, {'party': 'PP', 'name': 'LUIS RAÚL PICÓN QUEDO', 'vote': 'NO'}, {'party': 'FP', 'name': 'ARTURO ALEGRÍA GARCÍA', 'vote': 'SI'}, {'party': 'BM', 'name': 'PAUL SILVIO GUTIÉRREZ TICONA', 'vote': 'LP'}, {'party': 'PL', 'name': 'KELLY ROXANA PORTALATINO ÁVALOS', 'vote': 'aus'}, {'party': 'NA', 'name': 'MARÍA ALVA PRIETO', 'vote': 'SI'}, {'party': 'APP', 'name': 'NELCY HEIDINGER BALLESTEROS', 'vote': 'SI'}, {'party': 'AP', 'name': 'HILDA MARLENY PORTERO LÓPEZ', 'vote': 'LP'}, {'party': 'AP', 'name': 'CARLOS ENRIQUE ALVA ROJAS', 'vote': 'SI'}, {'party': 'RP', 'name': 'NOELIA ROSSVITH HERRERA MEDINA', 'vote': 'SI'}, {'party': 'BM', 'name': 'SEGUNDO TEODOMIRO QUIROZ BARBOZA', 'vote': 'SI'}, {'party': 'AP-PIS', 'name': 'YESSICA ROSSELLI AMURUZ DULANTO', 'vote': 'LE'}, {'party': 'FP', 'name': 'RAÚL HUAMÁN CORONADO', 'vote': 'SI'}, {'party': 'JPP-VP', 'name': 'WILSON RUSBEL QUISPE MAMANI', 'vote': 'NO'}, {'party': 'NA', 'name': 'CARLOS ANTONIO ANDERSON RAMÍREZ', 'vote': 'LE'}, {'party': 'FP', 'name': 'MERY ELIANA INFANTES CASTAÑEDA', 'vote': 'aus'}, {'party': 'BS', 'name': 'BERNARDO JAIME QUITO SARMIENTO', 'vote': 'NO'}, {'party': 'AP', 'name': 'LUIS ÁNGEL ARAGÓN CARREÑO', 'vote': 'aus'}, {'party': 'RP', 'name': 'DE AGUAYO JÁUREGUI MARTÍNEZ', 'vote': 'aus'}, {'party': 'FP', 'name': 'TANIA ESTEFANY RAMÍREZ GARCÍA', 'vote': 'SI'}, {'party': 'PP', 'name': 'JOSÉ ALBERTO ARRIOLA TUEROS', 'vote': 'Abst.'}, {'party': 'SP', 'name': 'JOSÉ ENRIQUE JERI ORÉ', 'vote': 'SI'}, {'party': 'FP', 'name': 'CÉSAR MANUEL REVILLA VILLANUEVA', 'vote': 'SI'}, {'party': 'sP', 'name': 'ALFREDO AZURÍN LOAYZA', 'vote': 'SI'}, {'party': 'FP', 'name': 'DAVID JULIO JIMÉNEZ HEREDIA', 'vote': 'SI'}, {'party': 'PL', 'name': 'ABEL AUGUSTO REYES CAM', 'vote': 'aus'}, {'party': 'PL', 'name': 'JOSÉ MARÍA BALCÁZAR ZELADA', 'vote': 'LE'}, {'party': 'PP', 'name': 'HEIDY LISSETH JUÁREZ CALLE', 'vote': 'NO'}, {'party': 'BDP', 'name': 'EDGARD CORNELIO REYMUNDO MERCADO', 'vote': 'NO'}, {'party': 'FP', 'name': 'ROSANGELLA ANDREA BARBARÁN REYES', 'vote': 'SI'}, {'party': 'FP', 'name': 'CARMEN PATRICIA JUÁREZ GALLEGOS'}, {'party': 'PL', 'name': 'JANET MILAGROS RIVAS CHACARA', 'vote': 'NO'}, {'party': 'RP', 'name': 'DIEGO ALONSO BAZÁN CALDERÓN', 'vote': 'aus'}, {'party': 'APP', 'name': 'ELVA EDHIT JULON IRIGOÍN', 'vote': 'SI'}, {'party': 'BS', 'name': 'SILVANA EMPERATRIZ ROBLES ARAUJO', 'vote': 'NO'}, {'party': 'BOP', 'name': 'SIGRID TESORO BAZÁN NARRO', 'vote': 'LP'}, {'party': 'APP', 'name': 'LUIS ROBERTO KAMICHE MORANTE', 'vote': 'SI'}, {'party': 'FP', 'name': 'FERNANDO MIGUEL ROSPIGLIOSI CAPURRO', 'vote': 'SI'}, {'party': 'PP', 'name': 'GUIDO BELLIDO UGARTE', 'vote': 'NO'}, {'party': 'JPP-VP', 'name': 'NIEVES ESMERALDA LIMACHI QUISPE', 'vote': 'NO'}, {'party': 'APP', 'name': 'MAGALY ROSMERY RUIZ RODRÍGUEZ', 'vote': 'LE'}, {'party': 'IJPP-VP', 'name': 'GUILLERMO BERMEJO ROJAS', 'vote': 'NO'}, {'party': 'APP', 'name': 'JUAN LIZARZABURU LIZARZABURU', 'vote': 'LE'}, {'party': 'APP', 'name': 'EDUARDO SALHUANA CAVIDES', 'vote': ...

# %%
with open("bill_vote.json", "w") as json_file:
    json.dump(final_list, json_file)
